# %% [markdown]
# To see a partial year match gives us any names

# %%
import pandas as pd
import re

# %%
cust_data=pd.read_csv('ScotiaBank_names.csv', parse_dates=['BIRTH_DT'])

# %%
cust_data['year']=cust_data['BIRTH_DT'].dt.year
cust_data['month']=cust_data['BIRTH_DT'].dt.month
cust_data['day']=cust_data['BIRTH_DT'].dt.day

# %%
cust_data
# Out:
#                                   NAME   BIRTH_DT  year  month  day
# 0          young marie mildren coleman 1981-09-01  1981      9    1
# 1                     mark stupar lecy 1994-02-21  1994      2   21
# 2           dean glasper wendel reeves 1962-11-16  1962     11   16
# 3                   hulsey linda rauth 1998-06-20  1998      6   20
# 4           carolyn washington roberts 1942-01-24  1942      1   24
# ...                                ...        ...   ...    ...  ...
# 999251                bret dove gainey 1939-01-16  1939      1   16
# 999252       anthony ray montano gomez 1970-12-13  1970     12   13
# 999253  bernadette schofield pace mile 1958-09-09  1958      9    9
# 999254          wasson russell terrell 1983-09-15  1983      9   15
# 999255                daniel mckeighan 1962-01-23  1962      1   23
#
# [999256 rows x 5 columns]

# %%
sanction=pd.read_csv('clean_sanction_name_v2.csv')

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0        0
# name              0
# aliases       80054
# birth_date    63364
# dtype: int64

# %%
sanction=sanction[sanction['birth_date'].notna()]

# %%
sanction['dob']=sanction['birth_date'].str.split(";").str[1]

# %%
sanction.shape
# Out:
# (143325, 5)

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0         0
# name               0
# aliases        34361
# birth_date         0
# dob           140156
# dtype: int64

# %%
sanction=sanction[sanction['dob'].notna()]

# %%
sanction
# Out:
#         Unnamed: 0                                    name  \
# 247            247  nasser abdul karim abdullah al-wahishi
# 284            284                     eugene kouadio djue
# 11432        11432          syed ahmed fathi hussein aliwa
# 11609        11609                   muhammad rasool ayyub
# 11621        11621            alexander igorevich kuvaldin
# ...            ...                                     ...
# 198545      238805                        shaykh aminullah
# 198547      238807                            stanley obas
# 198554      238814                   timothy thomas coombs
# 198557      238817                            trung duc lu
# 198573      238833                      wilfredo rodriguez
#
#                                                   aliases  \
# 247     Abdul Kareem Al-Woohaishi;Abu Baseer al-Wehais...
# 284                                                   NaN
# 11432   AL SAYYID AHMED FATHI HUSSEIN ELIWAH;Abu Umar;...
# 11609   GURG;Gurg;MOHAMMAD RASUL AYYUB;Mohammad Rasul ...
# 11621   Aleksandr Igorevich Kuvaldin;Kuvaldin Aleksand...
# ...                                                   ...
# 198545                                                NaN
# 198547                                                NaN
# 198554                                                NaN
# 198557                                                NaN
# 198573                                                NaN
#
#                                                birth_date         dob
# 247                                 1396-10-08;1976-10-01  1976-10-01
# 284                                 1966-01-01;1969-12-20  1969-12-20
# 11432                    1954-07-03;1964-01-30;1964-07-30  1964-01-30
# 11609                       1958;1959;1960;1961;1962;1963        1959
# 11621                                     1951;1980-12-15  1980-12-15
# ...                                                   ...         ...
# 198545                                     1961;1967;1973        1967
# 198547                              1976-09-24;1977-09-24  1977-09-24
# 198554                              1959-02-21;1959-07-07  1959-07-07
# 198557  1979-12-02;1979-12-09;1980-10-01;1980-11-13;19...  1979-12-09
# 198573                              1961-10-16;1963-11-08  1963-11-08
#
# [3169 rows x 5 columns]

# %%
sanction.dtypes
# Out:
# Unnamed: 0     int64
# name          object
# aliases       object
# birth_date    object
# dob           object
# dtype: object

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0      0
# name            0
# aliases       135
# birth_date      0
# dob             0
# dtype: int64

# %%
sanction['year']=sanction['dob'].str.split("-").str[0]

# %%
sanction['month']=sanction['dob'].str.split("-").str[1]

# %%
sanction['day']=sanction['dob'].str.split("-").str[2]

# %%
sanction
# Out:
#         Unnamed: 0                                    name  \
# 247            247  nasser abdul karim abdullah al-wahishi
# 284            284                     eugene kouadio djue
# 11432        11432          syed ahmed fathi hussein aliwa
# 11609        11609                   muhammad rasool ayyub
# 11621        11621            alexander igorevich kuvaldin
# ...            ...                                     ...
# 198545      238805                        shaykh aminullah
# 198547      238807                            stanley obas
# 198554      238814                   timothy thomas coombs
# 198557      238817                            trung duc lu
# 198573      238833                      wilfredo rodriguez
#
#                                                   aliases  \
# 247     Abdul Kareem Al-Woohaishi;Abu Baseer al-Wehais...
# 284                                                   NaN
# 11432   AL SAYYID AHMED FATHI HUSSEIN ELIWAH;Abu Umar;...
# 11609   GURG;Gurg;MOHAMMAD RASUL AYYUB;Mohammad Rasul ...
# 11621   Aleksandr Igorevich Kuvaldin;Kuvaldin Aleksand...
# ...                                                   ...
# 198545                                                NaN
# 198547                                                NaN
# 198554                                                NaN
# 198557                                                NaN
# 198573                                                NaN
#
#                                                birth_date         dob  year  \
# 247                                 1396-10-08;1976-10-01  1976-10-01  1976
# 284                                 1966-01-01;1969-12-20  1969-12-20  1969
# 11432                    1954-07-03;1964-01-30;1964-07-30  1964-01-30  1964
# 11609                       1958;1959;1960;1961;1962;1963        1959  1959
# 11621                                     1951;1980-12-15  1980-12-15  1980
# ...                                                   ...         ...   ...
# 198545                                     1961;1967;1973        1967  1967
# 198547                              1976-09-24;1977-09-24  1977-09-24  1977
# 198554                              1959-02-21;1959-07-07  1959-07-07  1959
# 198557  1979-12-02;1979-12-09;1980-10-01;1980-11-13;19...  1979-12-09  1979
# 198573                              1961-10-16;1963-11-08  1963-11-08  1963
#
#        month  day
# 247       10   01
# 284       12   20
# 11432     01   30
# 11609    NaN  NaN
# 11621     12   15
# ...      ...  ...
# 198545   NaN  NaN
# 198547    09   24
# 198554    07   07
# 198557    12   09
# 198573    11   08
#
# [3169 rows x 8 columns]

# %%
sanction.sort_values(by=['year'],inplace=True)

# %%
sanction
# Out:
#         Unnamed: 0                     name  \
# 141920      140161                 yin shun
# 43396        43396          osman bölükbaşı
# 34059        34059             ali tanriyar
# 138156      135361              zina harman
# 43426        43426           your faik kind
# ...            ...                      ...
# 34067        34067          aӏexey uӏyukaev
# 85301        57060               emraan ali
# 155972      157167         jumanne maghembe
# 149118      148677  alla yur yevna manilova
# 91907        69192    amy ambatobe nyongolo
#
#                                                   aliases  \
# 141920  Master Yin Shun;Yinshun;Yìnshùn;印順;印順導師;印順法師;印...
# 43396                     Osman Bolukbasi;Осман Бёлюкбаши
# 34059   Ali Tanriyar;Spor Ali;Али Танръяр;Али Танрыяр;...
# 138156   Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان
# 43426                                                 NaN
# ...                                                   ...
# 34067   Aleksei Uljukajev;Aleksei Ulukajev;Aleksei Uly...
# 85301   ALI, Emraan;Abu Jihad TNT;Ali;EMRAAN ALI;Emraa...
# 155972  Jumanne Abdallah Maghembe;Maghembe Abdallah Pr...
# 149118  Alla Jurevna Manilova;Alla Jurjevna Manilova;A...
# 91907                              Ami Ambatombe Nyongolo
#
#                    birth_date         dob  year month  day
# 141920  1906-03-12;1906-12-03  1906-12-03  1906    12   03
# 43396               1911;1913        1913  1913   NaN  NaN
# 34059   1914-01-01;1914-03-14  1914-03-14  1914    03   14
# 138156  1914-04-28;1914-08-28  1914-08-28  1914    08   28
# 43426         1913-10-17;1914        1914  1914   NaN  NaN
# ...                       ...         ...   ...   ...  ...
# 34067   1956-03-23;2016-11-15  2016-11-15  2016    11   15
# 85301         1967-07-04;2465        2465  2465   NaN  NaN
# 155972        1970;2951-08-24  2951-08-24  2951    08   24
# 149118  1957-07-16;2957-07-16  2957-07-16  2957    07   16
# 91907   1975-02-24;2975-02-24  2975-02-24  2975    02   24
#
# [3169 rows x 8 columns]

# %%
cust_data.sort_values(by=['year'],inplace=True)

# %%
cust_data
# Out:
#                                     NAME   BIRTH_DT  year  month  day
# 257201     kessler sherry dusel vanmeter 1880-09-10  1880      9   10
# 555564         rebecca mayne newman paik 1884-08-18  1884      8   18
# 9959      shane robertson gauted denison 1887-07-14  1887      7   14
# 614552           angel minor paocs marsh 1887-03-31  1887      3   31
# 654460              nance beverly varney 1891-08-25  1891      8   25
# ...                                  ...        ...   ...    ...  ...
# 771829        wanda odom barker eckerson 2019-01-05  2019      1    5
# 44463   hirz genevieve ogrodowicz lawson 2019-09-29  2019      9   29
# 173869                   pete synder oan 2019-04-27  2019      4   27
# 542421    robert brainard vandusen clark 2019-06-27  2019      6   27
# 855527           cortes janna lee campos 2019-01-31  2019      1   31
#
# [999256 rows x 5 columns]

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0      0
# name            0
# aliases       135
# birth_date      0
# dob             0
# year            0
# month         490
# day           514
# dtype: int64

# %% [markdown]
# select all rows where month and day is null

# %%
cust_data.dtypes
# Out:
# NAME                object
# BIRTH_DT    datetime64[ns]
# year                 int64
# month                int64
# day                  int64
# dtype: object

# %%
sanction['year']=sanction['year'].astype(int)

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0      0
# name            0
# aliases       135
# birth_date      0
# dob             0
# year            0
# month         490
# day           514
# dtype: int64

# %%
sanction=sanction[sanction['month'].notna() & sanction['day'].notna()]

# %%
sanction
# Out:
#         Unnamed: 0                             name  \
# 141920      140161                         yin shun
# 34059        34059                     ali tanriyar
# 138156      135361                      zina harman
# 154923      155808                   bernard braine
# 88293        64036                   igrejas caeiro
# ...            ...                              ...
# 82052        49984  kravchenko valeriy mykolayovych
# 34067        34067                  aӏexey uӏyukaev
# 155972      157167                 jumanne maghembe
# 149118      148677          alla yur yevna manilova
# 91907        69192            amy ambatobe nyongolo
#
#                                                   aliases  \
# 141920  Master Yin Shun;Yinshun;Yìnshùn;印順;印順導師;印順法師;印...
# 34059   Ali Tanriyar;Spor Ali;Али Танръяр;Али Танрыяр;...
# 138156   Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان
# 154923   Lord Braine of Wheatley;بيرنارد براين;バーナード・ブレイン
# 88293                            Francisco Igrejas Caeiro
# ...                                                   ...
# 82052   Kravchenko Valeri Nikolaevich;Kravchenko Valer...
# 34067   Aleksei Uljukajev;Aleksei Ulukajev;Aleksei Uly...
# 155972  Jumanne Abdallah Maghembe;Maghembe Abdallah Pr...
# 149118  Alla Jurevna Manilova;Alla Jurjevna Manilova;A...
# 91907                              Ami Ambatombe Nyongolo
#
#                    birth_date         dob  year month day
# 141920  1906-03-12;1906-12-03  1906-12-03  1906    12  03
# 34059   1914-01-01;1914-03-14  1914-03-14  1914    03  14
# 138156  1914-04-28;1914-08-28  1914-08-28  1914    08  28
# 154923  1914-06-21;1914-06-24  1914-06-24  1914    06  24
# 88293   1917-08-15;1917-08-18  1917-08-18  1917    08  18
# ...                       ...         ...   ...   ...  ..
# 82052   1947-01-01;2016-10-05  2016-10-05  2016    10  05
# 34067   1956-03-23;2016-11-15  2016-11-15  2016    11  15
# 155972        1970;2951-08-24  2951-08-24  2951    08  24
# 149118  1957-07-16;2957-07-16  2957-07-16  2957    07  16
# 91907   1975-02-24;2975-02-24  2975-02-24  2975    02  24
#
# [2655 rows x 8 columns]

# %%
sanction.loc[sanction.index[-1], 'dob']='1975-02-24'
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
sanction.loc[sanction.index[-2], 'dob']='1957-07-16'

# %%
sanction.loc[sanction.index[-3], 'dob']='1951-08-24'

# %%
sanction
# Out:
#         Unnamed: 0                             name  \
# 141920      140161                         yin shun
# 34059        34059                     ali tanriyar
# 138156      135361                      zina harman
# 154923      155808                   bernard braine
# 88293        64036                   igrejas caeiro
# ...            ...                              ...
# 82052        49984  kravchenko valeriy mykolayovych
# 34067        34067                  aӏexey uӏyukaev
# 155972      157167                 jumanne maghembe
# 149118      148677          alla yur yevna manilova
# 91907        69192            amy ambatobe nyongolo
#
#                                                   aliases  \
# 141920  Master Yin Shun;Yinshun;Yìnshùn;印順;印順導師;印順法師;印...
# 34059   Ali Tanriyar;Spor Ali;Али Танръяр;Али Танрыяр;...
# 138156   Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان
# 154923   Lord Braine of Wheatley;بيرنارد براين;バーナード・ブレイン
# 88293                            Francisco Igrejas Caeiro
# ...                                                   ...
# 82052   Kravchenko Valeri Nikolaevich;Kravchenko Valer...
# 34067   Aleksei Uljukajev;Aleksei Ulukajev;Aleksei Uly...
# 155972  Jumanne Abdallah Maghembe;Maghembe Abdallah Pr...
# 149118  Alla Jurevna Manilova;Alla Jurjevna Manilova;A...
# 91907                              Ami Ambatombe Nyongolo
#
#                    birth_date         dob  year month day
# 141920  1906-03-12;1906-12-03  1906-12-03  1906    12  03
# 34059   1914-01-01;1914-03-14  1914-03-14  1914    03  14
# 138156  1914-04-28;1914-08-28  1914-08-28  1914    08  28
# 154923  1914-06-21;1914-06-24  1914-06-24  1914    06  24
# 88293   1917-08-15;1917-08-18  1917-08-18  1917    08  18
# ...                       ...         ...   ...   ...  ..
# 82052   1947-01-01;2016-10-05  2016-10-05  2016    10  05
# 34067   1956-03-23;2016-11-15  2016-11-15  2016    11  15
# 155972        1970;2951-08-24  1951-08-24  2951    08  24
# 149118  1957-07-16;2957-07-16  1957-07-16  2957    07  16
# 91907   1975-02-24;2975-02-24  1975-02-24  2975    02  24
#
# [2655 rows x 8 columns]

# %%
sanction=sanction[['name','aliases','dob']]

# %%
sanction
# Out:
#                                    name  \
# 141920                         yin shun
# 34059                      ali tanriyar
# 138156                      zina harman
# 154923                   bernard braine
# 88293                    igrejas caeiro
# ...                                 ...
# 82052   kravchenko valeriy mykolayovych
# 34067                   aӏexey uӏyukaev
# 155972                 jumanne maghembe
# 149118          alla yur yevna manilova
# 91907             amy ambatobe nyongolo
#
#                                                   aliases         dob
# 141920  Master Yin Shun;Yinshun;Yìnshùn;印順;印順導師;印順法師;印...  1906-12-03
# 34059   Ali Tanriyar;Spor Ali;Али Танръяр;Али Танрыяр;...  1914-03-14
# 138156   Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان  1914-08-28
# 154923   Lord Braine of Wheatley;بيرنارد براين;バーナード・ブレイン  1914-06-24
# 88293                            Francisco Igrejas Caeiro  1917-08-18
# ...                                                   ...         ...
# 82052   Kravchenko Valeri Nikolaevich;Kravchenko Valer...  2016-10-05
# 34067   Aleksei Uljukajev;Aleksei Ulukajev;Aleksei Uly...  2016-11-15
# 155972  Jumanne Abdallah Maghembe;Maghembe Abdallah Pr...  1951-08-24
# 149118  Alla Jurevna Manilova;Alla Jurjevna Manilova;A...  1957-07-16
# 91907                              Ami Ambatombe Nyongolo  1975-02-24
#
# [2655 rows x 3 columns]

# %%
sanction.rename(columns={'dob':'BIRTH_DT'},inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
cust_data
# Out:
#                                     NAME   BIRTH_DT  year  month  day
# 257201     kessler sherry dusel vanmeter 1880-09-10  1880      9   10
# 555564         rebecca mayne newman paik 1884-08-18  1884      8   18
# 9959      shane robertson gauted denison 1887-07-14  1887      7   14
# 614552           angel minor paocs marsh 1887-03-31  1887      3   31
# 654460              nance beverly varney 1891-08-25  1891      8   25
# ...                                  ...        ...   ...    ...  ...
# 771829        wanda odom barker eckerson 2019-01-05  2019      1    5
# 44463   hirz genevieve ogrodowicz lawson 2019-09-29  2019      9   29
# 173869                   pete synder oan 2019-04-27  2019      4   27
# 542421    robert brainard vandusen clark 2019-06-27  2019      6   27
# 855527           cortes janna lee campos 2019-01-31  2019      1   31
#
# [999256 rows x 5 columns]

# %%
sanction['BIRTH_DT']=pd.to_datetime(sanction['BIRTH_DT'])
# Out:
# <ipython-input-37-6b2e93fde8e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sanction['BIRTH_DT']=pd.to_datetime(sanction['BIRTH_DT'])

# %%
cust_data['BIRTH_DT']=pd.to_datetime(cust_data['BIRTH_DT'])

# %%
cust_data.dtypes
# Out:
# NAME                object
# BIRTH_DT    datetime64[ns]
# year                 int64
# month                int64
# day                  int64
# dtype: object

# %%
sanction.isna().sum()
# Out:
# name          0
# aliases     122
# BIRTH_DT      0
# dtype: int64

# %%
sanction.dtypes
# Out:
# name                object
# aliases             object
# BIRTH_DT    datetime64[ns]
# dtype: object

# %%
x=sanction.merge(cust_data,on=['BIRTH_DT'])

# %%
x.shape
# Out:
# (118473, 7)

# %%
x
# Out:
#                          name  \
# 0                ali tanriyar
# 1                 zina harman
# 2                 zina harman
# 3                 zina harman
# 4              bernard braine
# ...                       ...
# 118468  amy ambatobe nyongolo
# 118469  amy ambatobe nyongolo
# 118470  amy ambatobe nyongolo
# 118471  amy ambatobe nyongolo
# 118472  amy ambatobe nyongolo
#
#                                                   aliases   BIRTH_DT  \
# 0       Ali Tanriyar;Spor Ali;Али Танръяр;Али Танрыяр;... 1914-03-14
# 1        Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان 1914-08-28
# 2        Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان 1914-08-28
# 3        Zina Harmanová;Zina Herman;זינה הרמן;زينا هارمان 1914-08-28
# 4        Lord Braine of Wheatley;بيرنارد براين;バーナード・ブレイン 1914-06-24
# ...                                                   ...        ...
# 118468                             Ami Ambatombe Nyongolo 1975-02-24
# 118469                             Ami Ambatombe Nyongolo 1975-02-24
# 118470                             Ami Ambatombe Nyongolo 1975-02-24
# 118471                             Ami Ambatombe Nyongolo 1975-02-24
# 118472                             Ami Ambatombe Nyongolo 1975-02-24
#
#                                    NAME  year  month  day
# 0          raymond harding edwards dean  1914      3   14
# 1                           kerns twyla  1914      8   28
# 2           audette joyce meadows gross  1914      8   28
# 3        lloyd hendrickson lynn mcwhite  1914      8   28
# 4                   cooper emanuel pike  1914      6   24
# ...                                 ...   ...    ...  ...
# 118468       wanda raub mgerard sanchez  1975      2   24
# 118469  mitchell tom blankenship rainge  1975      2   24
# 118470    alexis bunning brooks stalcup  1975      2   24
# 118471             spann michelle olsen  1975      2   24
# 118472       houston elizabeth difranco  1975      2   24
#
# [118473 rows x 7 columns]

# %%
pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
pip install python-levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 4.6 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-levenshtein
# Successfully installed Levenshtein-0.20.9 python-levenshtein-0.20.9 rapidfuzz-2.13.7

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
def fuzzyscore(col):
  return fuzz.token_sort_ratio(col['NAME'],col['name'])

# %%
x['score']=x.apply(fuzzyscore,axis=1)

# %%
x.sort_values(by=['score'],inplace=True)

# %%
res=x[x['score']>=60]

# %%
res
# Out:
#                                     name  \
# 64497                         soren pind
# 97832                       jose ramirez
# 34412                       keir starmer
# 3159                         harald ettl
# 66892                      mike ferguson
# 88497                  peter christensen
# 38364                     song young gil
# 61066                   mardani ali sera
# 28281                    william moorlag
# 8049                   ayman al zawahiri
# 6706                    charles lee hill
# 103129             raul hernandez barron
# 73551                  jason derek brown
# 49869                fuad mohamed khalaf
# 52452     andrey konstantinovich lugovoy
# 112848                      omar hammami
# 107273                      peter cherif
# 104012  natalia vladimirovna poklonskaya
#
#                                                   aliases   BIRTH_DT  \
# 64497         Soren Pind;Сорен Пінд;سورين پيند;索倫·平德;쇠렌 핀 1969-11-20
# 97832                                                 NaN 1978-11-17
# 34412   Keir Rodney Starmer;Sir Keir Rodney Starmer;Si... 1962-09-20
# 3159                                           هارالد اتل 1947-12-17
# 66892   Ferguson;Ferguson, Michael;Mike Ferguson (New ... 1970-07-22
# 88497   Petrus Christensen;Питер Кристенсен;بيتر كريستنسن 1975-04-25
# 38364   SONG YOUNGGIL;Song Young Gil;Szong Jonggil;Сон... 1963-03-21
# 61066   DR. H. MARDANI, M.Eng;Dr H Mardani M Eng;Dr. H... 1968-09-04
# 28281   Moorlag, W.J.;W.J. Moorlag;William Johannes Mo... 1960-04-17
# 8049    AIMAN MUHAMMED RABI AL-ZAWAHIRI;AIMAN MUHAMMED... 1951-06-19
# 6706                                                  NaN 1950-10-04
# 103129       HERNANDEZ BARRON, Raul;Raúl Hernández Barrón 1980-10-16
# 73551   Jason Derek Brown;جيسون ديريك براون;جیسون دراک... 1971-01-17
# 49869   FUAD MOHAMED KHALAF;Fouad SHONGALE;Fouad Shong... 1965-05-28
# 52452   Andrei (Andrey) Lugovoi (Lugovoy);Andrei Konst... 1966-10-19
# 112848  AL-AMRIKI, Abu Mansour;AL-AMRIKI, Abu Mansur;A... 1986-05-06
# 107273  CHERAF, Abu Hamza;CHERAF, Peter;CHERIF, Peter;... 1982-08-26
# 104012  Dubrovskaia Natalia Vladimirovna;Dubrovskaja N... 1980-03-18
#
#                                      NAME  year  month  day  score
# 64497                          olson gina  1969     11   20     60
# 97832                  diane ramirez wong  1978     11   17     60
# 34412                         jerry stern  1962      9   20     61
# 3159                         fossett raul  1947     12   17     61
# 66892                          fehr marie  1970      7   22     61
# 88497                    christine norris  1975      4   25     61
# 38364                 henry young johnson  1963      3   21     61
# 61066                          warner kal  1968      9    4     62
# 28281                      hazel williams  1960      4   17     62
# 8049      al zawahiri aiman muhammad rabi  1951      6   19     62
# 6706                charles perez johnson  1950     10    4     65
# 103129           dolly hernandez day rash  1980     10   16     67
# 73551               barney george jackson  1971      1   17     68
# 49869       shongole fuad muhammad khalaf  1965      5   28     71
# 52452    andrei konstantinowitsj loegowoi  1966     10   19     74
# 112848                hammami omar shafik  1986      5    6     77
# 107273                       cheraf peter  1982      8   26     92
# 104012  poklonskaya natalija vladimirovna  1980      3   18     98

# %%
res.to_csv('new_names.csv')
