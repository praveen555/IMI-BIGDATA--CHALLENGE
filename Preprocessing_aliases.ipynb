# %% [markdown]
# <a href="https://colab.research.google.com/github/praveen555/IMI-BIGDATA--CHALLENGE/blob/main/Preprocessing_aliases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sanction=pd.read_csv('clean_sanction_name_v3.csv')

# %%
sanction
# Out:
#         Unnamed: 0                                name  \
# 0            12668            rachek yulia mykhailovna
# 1            56668                          josef duss
# 2            61063                        amedeo boffa
# 3            68472                       georges borel
# 4            56086                       alfred jaunin
# ...            ...                                 ...
# 125531        7854             julio ixcamey velasquez
# 125532      106605           rebeca grajea de la torre
# 125533       53347          birgalin ainur azamatovich
# 125534      193447             ivan olegovich chemezov
# 125535      189437  vyacheslav vladimirovich eliseenko
#
#                                                   aliases    BIRTH_DT
# 0                     Rachek Yuliia;Рачек Юлия Михайловна  1885-09-23
# 1                                             Duss, Josef  1900-12-26
# 2                                           Boffa, Amedeo  1900-08-03
# 3                                          Borel, Georges  1900-06-06
# 4                                          Jaunin, Alfred  1900-06-17
# ...                                                   ...         ...
# 125531                                                NaN  2016-01-20
# 125532                                                NaN  2019-01-30
# 125533                          Биргалин Айнур Азаматович  2019-10-16
# 125534  Chemezov Ivan Olegovich;Čemezov Ivan Olegovič;...  2019-08-21
# 125535  Eliseenko Viacheslav Vladimirovich;Eliseenko V...  2019-05-31
#
# [125536 rows x 4 columns]

# %%
sanction.isna().sum()
# Out:
# Unnamed: 0        0
# name              0
# aliases       25832
# BIRTH_DT          0
# dtype: int64

# %%
import unicodedata
output = unicodedata.normalize('NFD',"Rachek Yuliia;Рачек Юлия Михайловна").encode('ascii', 'ignore')
print(output.decode("utf-8"))
# Out:
# Rachek Yuliia;

# %%
sanction['aliases']=sanction['aliases'].str.replace(","," ")

# %%
sanction
# Out:
#         Unnamed: 0                                name  \
# 0            12668            rachek yulia mykhailovna
# 1            56668                          josef duss
# 2            61063                        amedeo boffa
# 3            68472                       georges borel
# 4            56086                       alfred jaunin
# ...            ...                                 ...
# 125531        7854             julio ixcamey velasquez
# 125532      106605           rebeca grajea de la torre
# 125533       53347          birgalin ainur azamatovich
# 125534      193447             ivan olegovich chemezov
# 125535      189437  vyacheslav vladimirovich eliseenko
#
#                                                   aliases    BIRTH_DT
# 0                     Rachek Yuliia;Рачек Юлия Михайловна  1885-09-23
# 1                                             Duss  Josef  1900-12-26
# 2                                           Boffa  Amedeo  1900-08-03
# 3                                          Borel  Georges  1900-06-06
# 4                                          Jaunin  Alfred  1900-06-17
# ...                                                   ...         ...
# 125531                                                NaN  2016-01-20
# 125532                                                NaN  2019-01-30
# 125533                          Биргалин Айнур Азаматович  2019-10-16
# 125534  Chemezov Ivan Olegovich;Čemezov Ivan Olegovič;...  2019-08-21
# 125535  Eliseenko Viacheslav Vladimirovich;Eliseenko V...  2019-05-31
#
# [125536 rows x 4 columns]

# %%
# def english_only(col):
#   output=unicodedata.normalize('NFD',str(col)).encode('ascii', 'ignore')
#   return output.decode("utf-8")

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")","*","+",",","-",".","/",":",";","<","=",">","?","@","[","\\","]","^","_","`","{","|","}","~","–","’","“","”","‘","´"]

# %%
sanction.dtypes
# Out:
# Unnamed: 0     int64
# name          object
# aliases       object
# BIRTH_DT      object
# dtype: object

# %%
sanction
# Out:
#         Unnamed: 0                                name  \
# 0            12668            rachek yulia mykhailovna
# 1            56668                          josef duss
# 2            61063                        amedeo boffa
# 3            68472                       georges borel
# 4            56086                       alfred jaunin
# ...            ...                                 ...
# 125531        7854             julio ixcamey velasquez
# 125532      106605           rebeca grajea de la torre
# 125533       53347          birgalin ainur azamatovich
# 125534      193447             ivan olegovich chemezov
# 125535      189437  vyacheslav vladimirovich eliseenko
#
#                                                   aliases    BIRTH_DT
# 0                     Rachek Yuliia;Рачек Юлия Михайловна  1885-09-23
# 1                                             Duss  Josef  1900-12-26
# 2                                           Boffa  Amedeo  1900-08-03
# 3                                          Borel  Georges  1900-06-06
# 4                                          Jaunin  Alfred  1900-06-17
# ...                                                   ...         ...
# 125531                                                NaN  2016-01-20
# 125532                                                NaN  2019-01-30
# 125533                          Биргалин Айнур Азаматович  2019-10-16
# 125534  Chemezov Ivan Olegovich;Čemezov Ivan Olegovič;...  2019-08-21
# 125535  Eliseenko Viacheslav Vladimirovich;Eliseenko V...  2019-05-31
#
# [125536 rows x 4 columns]

# %%
from string import punctuation
def clean_text(text):
  token=str(text).split(";")
  #tokens = [word for word in token if word.isascii()==False]
  #table = str.maketrans("","",punctuation)
  #token = [word.translate(table) for word in token]
  #words=[word.replace("","""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""") for word in token]
  words=[word.lower() for word in token]
  return words

# %%
sanction['aliases']=sanction['aliases'].apply(clean_text)

# %%
sanction
# Out:
#         Unnamed: 0                                name  \
# 0            12668            rachek yulia mykhailovna
# 1            56668                          josef duss
# 2            61063                        amedeo boffa
# 3            68472                       georges borel
# 4            56086                       alfred jaunin
# ...            ...                                 ...
# 125531        7854             julio ixcamey velasquez
# 125532      106605           rebeca grajea de la torre
# 125533       53347          birgalin ainur azamatovich
# 125534      193447             ivan olegovich chemezov
# 125535      189437  vyacheslav vladimirovich eliseenko
#
#                                                   aliases    BIRTH_DT
# 0                  [rachek yuliia, рачек юлия михайловна]  1885-09-23
# 1                                           [duss  josef]  1900-12-26
# 2                                         [boffa  amedeo]  1900-08-03
# 3                                        [borel  georges]  1900-06-06
# 4                                        [jaunin  alfred]  1900-06-17
# ...                                                   ...         ...
# 125531                                              [nan]  2016-01-20
# 125532                                              [nan]  2019-01-30
# 125533                        [биргалин айнур азаматович]  2019-10-16
# 125534  [chemezov ivan olegovich, čemezov ivan olegovi...  2019-08-21
# 125535  [eliseenko viacheslav vladimirovich, eliseenko...  2019-05-31
#
# [125536 rows x 4 columns]

# %%
# def unique_names(x):
#     text=x.strip()
#     text=text.lower()
#     text=str(x).split(" ")
#     text=set(text)
#     #print(text)
#     return (" ".join(list(text)))

# %%
# non_na_sanction['eng_aliases'].head(5).apply(unique_names)

# %%
pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
pip install python-levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 5.1 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-levenshtein
# Successfully installed Levenshtein-0.20.9 python-levenshtein-0.20.9 rapidfuzz-2.13.7

# %%
cust_name=pd.read_csv('ScotiaBank_names_v1.csv')

# %%
cust_name
# Out:
#         Unnamed: 0  CUSTOMER_ID                            NAME    BIRTH_DT
# 0                0       935382     young marie mildren coleman  1981-09-01
# 1                1         2305                mark stupar lecy  1994-02-21
# 2                2       472403      dean glasper wendel reeves  1962-11-16
# 3                3       227994              hulsey linda rauth  1998-06-20
# 4                4       418265      carolyn washington roberts  1942-01-24
# ...            ...          ...                             ...         ...
# 999251      999995       420884                bret dove gainey  1939-01-16
# 999252      999996       429418       anthony ray montano gomez  1970-12-13
# 999253      999997       731360  bernadette schofield pace mile  1958-09-09
# 999254      999998       837988          wasson russell terrell  1983-09-15
# 999255      999999       166357                daniel mckeighan  1962-01-23
#
# [999256 rows x 4 columns]

# %%
df=cust_name.merge(sanction,on=['BIRTH_DT'])

# %%
df.shape
# Out:
# (5252141, 7)

# %%
df
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                         NAME    BIRTH_DT  \
# 0                   0       935382  young marie mildren coleman  1981-09-01
# 1                   0       935382  young marie mildren coleman  1981-09-01
# 2                   0       935382  young marie mildren coleman  1981-09-01
# 3                   0       935382  young marie mildren coleman  1981-09-01
# 4                   0       935382  young marie mildren coleman  1981-09-01
# ...               ...          ...                          ...         ...
# 5252136        994339       961724              june vick fultz  1921-04-21
# 5252137        994339       961724              june vick fultz  1921-04-21
# 5252138        998751        71494           nick tamayo turner  1925-08-31
# 5252139        998751        71494           nick tamayo turner  1925-08-31
# 5252140        998751        71494           nick tamayo turner  1925-08-31
#
#          Unnamed: 0_y                  name  \
# 0              123654     inger lise hansen
# 1               30108  jose ignacio beating
# 2              139388           terry healy
# 3               32779         raphael weber
# 4               71473         adrian cusiac
# ...               ...                   ...
# 5252136        127292       nicolaus dreyer
# 5252137         55811       pierre teuscher
# 5252138        179772       shirley walters
# 5252139         89282        paolo tringali
# 5252140        158119         dewey l  hill
#
#                                                    aliases
# 0                                                    [nan]
# 1        [jose ignacio paliza, jose paliza, josé ignaci...
# 2                         [terence james healy, تيري هيلي]
# 3                                            [рафал вебер]
# 4                                                    [nan]
# ...                                                    ...
# 5252136          [dreyer!, nikolaus dreyer, نيكولاوس درير]
# 5252137                                 [teuscher  pierre]
# 5252138  [mary shirley walters, mary walters, walters  ...
# 5252139                                              [nan]
# 5252140  [dewey lewis hill, ديوى ال. هيل, ديوي إل. هيل,...
#
# [5252141 rows x 7 columns]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
def fuzzyscore(col):
  return fuzz.token_set_ratio(col['NAME'],col['name'])

# %%
df['name_score']=df.apply(fuzzyscore,axis=1)

# %%
def fuzzyscore_2(col):
  return process.extractOne(col['NAME'],col['aliases'],scorer=fuzz.token_set_ratio)

# %%
df
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                         NAME    BIRTH_DT  \
# 0                   0       935382  young marie mildren coleman  1981-09-01
# 1                   0       935382  young marie mildren coleman  1981-09-01
# 2                   0       935382  young marie mildren coleman  1981-09-01
# 3                   0       935382  young marie mildren coleman  1981-09-01
# 4                   0       935382  young marie mildren coleman  1981-09-01
# ...               ...          ...                          ...         ...
# 5252136        994339       961724              june vick fultz  1921-04-21
# 5252137        994339       961724              june vick fultz  1921-04-21
# 5252138        998751        71494           nick tamayo turner  1925-08-31
# 5252139        998751        71494           nick tamayo turner  1925-08-31
# 5252140        998751        71494           nick tamayo turner  1925-08-31
#
#          Unnamed: 0_y                  name  \
# 0              123654     inger lise hansen
# 1               30108  jose ignacio beating
# 2              139388           terry healy
# 3               32779         raphael weber
# 4               71473         adrian cusiac
# ...               ...                   ...
# 5252136        127292       nicolaus dreyer
# 5252137         55811       pierre teuscher
# 5252138        179772       shirley walters
# 5252139         89282        paolo tringali
# 5252140        158119         dewey l  hill
#
#                                                    aliases  name_score
# 0                                                    [nan]          36
# 1        [jose ignacio paliza, jose paliza, josé ignaci...          34
# 2                         [terence james healy, تيري هيلي]          32
# 3                                            [рафал вебер]          25
# 4                                                    [nan]          30
# ...                                                    ...         ...
# 5252136          [dreyer!, nikolaus dreyer, نيكولاوس درير]          27
# 5252137                                 [teuscher  pierre]          20
# 5252138  [mary shirley walters, mary walters, walters  ...          36
# 5252139                                              [nan]          38
# 5252140  [dewey lewis hill, ديوى ال. هيل, ديوي إل. هيل,...          13
#
# [5252141 rows x 8 columns]

# %%
df.head(10).apply(fuzzyscore_2,axis=1)
# Out:
# 0                          (nan, 20)
# 1    (josé ignacio paliza nouel, 27)
# 2          (terence james healy, 39)
# 3                   (рафал вебер, 5)
# 4                          (nan, 20)
# 5             (zelimir petrovic, 33)
# 6         (anaya orozco alfredo, 34)
# 7                 (warman  matt, 37)
# 8                          (nan, 14)
# 9    (josé ignacio paliza nouel, 33)
# dtype: object

# %%
df['aliases_score']=df.apply(fuzzyscore_2,axis=1)

# %%
df
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                         NAME    BIRTH_DT  \
# 0                   0       935382  young marie mildren coleman  1981-09-01
# 1                   0       935382  young marie mildren coleman  1981-09-01
# 2                   0       935382  young marie mildren coleman  1981-09-01
# 3                   0       935382  young marie mildren coleman  1981-09-01
# 4                   0       935382  young marie mildren coleman  1981-09-01
# ...               ...          ...                          ...         ...
# 5252136        994339       961724              june vick fultz  1921-04-21
# 5252137        994339       961724              june vick fultz  1921-04-21
# 5252138        998751        71494           nick tamayo turner  1925-08-31
# 5252139        998751        71494           nick tamayo turner  1925-08-31
# 5252140        998751        71494           nick tamayo turner  1925-08-31
#
#          Unnamed: 0_y                  name  \
# 0              123654     inger lise hansen
# 1               30108  jose ignacio beating
# 2              139388           terry healy
# 3               32779         raphael weber
# 4               71473         adrian cusiac
# ...               ...                   ...
# 5252136        127292       nicolaus dreyer
# 5252137         55811       pierre teuscher
# 5252138        179772       shirley walters
# 5252139         89282        paolo tringali
# 5252140        158119         dewey l  hill
#
#                                                    aliases  name_score  \
# 0                                                    [nan]          36
# 1        [jose ignacio paliza, jose paliza, josé ignaci...          34
# 2                         [terence james healy, تيري هيلي]          32
# 3                                            [рафал вебер]          25
# 4                                                    [nan]          30
# ...                                                    ...         ...
# 5252136          [dreyer!, nikolaus dreyer, نيكولاوس درير]          27
# 5252137                                 [teuscher  pierre]          20
# 5252138  [mary shirley walters, mary walters, walters  ...          36
# 5252139                                              [nan]          38
# 5252140  [dewey lewis hill, ديوى ال. هيل, ديوي إل. هيل,...          13
#
#                            aliases_score
# 0                              (nan, 20)
# 1        (josé ignacio paliza nouel, 27)
# 2              (terence james healy, 39)
# 3                       (рафал вебер, 5)
# 4                              (nan, 20)
# ...                                  ...
# 5252136            (nikolaus dreyer, 27)
# 5252137           (teuscher  pierre, 20)
# 5252138               (mary walters, 47)
# 5252139                        (nan, 29)
# 5252140           (dewey lewis hill, 18)
#
# [5252141 rows x 9 columns]

# %%
df.sort_values(['name_score'],ascending=False,inplace=True)

# %%
df
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                       NAME    BIRTH_DT  \
# 3910079        983455        52501        samantha lewthwaite  1983-12-05
# 4710735        729524       592809   herlinto chamorro acosta  1956-01-10
# 2174042        126842       765620  trinidad y ramirez angelo  1978-03-20
# 2786695        983626       139717  alexey alexeyevich gromov  1960-05-31
# 395813         313484       894044            hlaing min aung  1956-07-03
# ...               ...          ...                        ...         ...
# 3006079        214633       776410      jennifer winn baldwin  1981-02-11
# 474537         235841        86706        peter britton byrne  1955-04-03
# 4489580        727054       224133                       mick  1969-10-20
# 1285367        953660       876201               muriel smith  1976-08-24
# 1021814        833508       110124  cardona agne everett chew  1956-12-02
#
#          Unnamed: 0_y                              name  \
# 3910079        114182               samantha lewthwaite
# 4710735        148081  eliecer herlinto chamorro acosta
# 2174042         86210           angelo ramirez trinidad
# 2786695        148212         alexey alexeyevich gromov
# 395813         143975                   min aung hlaing
# ...               ...                               ...
# 3006079         94010                               tum
# 474537         187627                            achmad
# 4489580        180244                  sudarshan bhagat
# 1285367        132103                         yang yang
# 1021814        132110                       yusuf yusuf
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 2174042  [angelo ramirez trinidad, abdukahlil, abdul kh...         100
# 2786695  [a. gromov, aleksei gromov, aleksej aleksejevi...         100
# 395813   [el pinochet birmano, hlaing  min aung, jenera...         100
# ...                                                    ...         ...
# 3006079           [deputado tum, wallison oliveira torres]           0
# 474537   [drs. h. achmad  m.si, drs. h. achmad  m.si., ...           0
# 4489580  [bhagat  shri sudarshan, सुदर्शन भगत, સુદર્શન ...           0
# 1285367  [jang jang, yang yang (a), ян ян, يانغ يانغ, ی...           0
# 1021814  [alhaji yusuf abubakar yusuf, yusuf abubakar y...           0
#
#                                    aliases_score
# 3910079        (samantha louise lewthwaite, 100)
# 4710735  (eliecer herlinto chamorro acosta, 100)
# 2174042           (angelo ramirez trinidad, 100)
# 2786695         (alexey alexeyevich gromov, 100)
# 395813                   (hlaing  min aung, 100)
# ...                                          ...
# 3006079           (wallison oliveira torres, 40)
# 474537                (drs. h. achmad  m.si, 17)
# 4489580              (bhagat  shri sudarshan, 8)
# 1285367                      (yang yang (a), 11)
# 1021814        (alhaji yusuf abubakar yusuf, 26)
#
# [5252141 rows x 9 columns]

# %%
df_threshold=df[df['name_score']>=70]

# %%
df_threshold.shape
# Out:
# (670, 9)

# %%
df_threshold['aliases_name']=df_threshold['aliases_score'].str[0]
df_threshold['aliases_score']=df_threshold['aliases_score'].str[1]
# Out:
# <ipython-input-72-aca1e1398783>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_threshold['aliases_name']=df_threshold['aliases_score'].str[0]
# <ipython-input-72-aca1e1398783>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_threshold['aliases_score']=df_threshold['aliases_score'].str[1]

# %%
df_threshold
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                         NAME    BIRTH_DT  \
# 3910079        983455        52501          samantha lewthwaite  1983-12-05
# 4710735        729524       592809     herlinto chamorro acosta  1956-01-10
# 2174042        126842       765620    trinidad y ramirez angelo  1978-03-20
# 2786695        983626       139717    alexey alexeyevich gromov  1960-05-31
# 395813         313484       894044              hlaing min aung  1956-07-03
# ...               ...          ...                          ...         ...
# 521829         340103       286973     amy hooper alberto scott  1964-07-14
# 5096589        799762       935871  lindquist elizabeth johnson  1953-11-22
# 3913044        728491       823635     williams timothy cassady  1968-10-24
# 3069496        904388       352465              nicholas gibson  1960-04-09
# 4772845        470116        77655     charles campbell wiseman  1942-12-03
#
#          Unnamed: 0_y                              name  \
# 3910079        114182               samantha lewthwaite
# 4710735        148081  eliecer herlinto chamorro acosta
# 2174042         86210           angelo ramirez trinidad
# 2786695        148212         alexey alexeyevich gromov
# 395813         143975                   min aung hlaing
# ...               ...                               ...
# 521829         145092                     alberto nigra
# 5096589        157190                     craig johnson
# 3913044        179349                   sandra williams
# 3069496         27188            alfredo bejos nicholas
# 4772845        156535                     charles ugwuh
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 2174042  [angelo ramirez trinidad, abdukahlil, abdul kh...         100
# 2786695  [a. gromov, aleksei gromov, aleksej aleksejevi...         100
# 395813   [el pinochet birmano, hlaing  min aung, jenera...         100
# ...                                                    ...         ...
# 521829                                     [البيرتو نيجرا]          70
# 5096589  [craig johnson (alaska politician), крэйг джон...          70
# 3913044  [сандра уильямс, ساندرا وليامز, ساندرا ویلیامز...          70
# 3069496  [alfredo bejos nicolas, bejos nicolás alfredo,...          70
# 4772845                        [charles chukwuemeka ugwuh]          70
#
#          aliases_score                       aliases_name
# 3910079            100         samantha louise lewthwaite
# 4710735            100   eliecer herlinto chamorro acosta
# 2174042            100            angelo ramirez trinidad
# 2786695            100          alexey alexeyevich gromov
# 395813             100                   hlaing  min aung
# ...                ...                                ...
# 521829               5                      البيرتو نيجرا
# 5096589             48  craig johnson (alaska politician)
# 3913044              5                     сандра уильямс
# 3069496             56              alfredo bejos nicolas
# 4772845             53          charles chukwuemeka ugwuh
#
# [670 rows x 10 columns]

# %%
x=df_threshold[(df_threshold['aliases_score']>=80)]

# %%
x.sort_values(['aliases_score'],inplace=True,ascending=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
x
# Out:
#          Unnamed: 0_x  CUSTOMER_ID                            NAME  \
# 3910079        983455        52501             samantha lewthwaite
# 63299          983620       711085           sayeed hafez mohammad
# 3949303        989300       507823             ali abd allah salih
# 4710735        729524       592809        herlinto chamorro acosta
# 4502076        989303       165089        viktor petrovitsj ivanov
# ...               ...          ...                             ...
# 2135354        971824       587233               chandra hernandez
# 1738556         22394       424548     robles michael doby sanchez
# 1249796        822607       751322     davis betty campbell bowman
# 1249586         63515       699067  campbell phyllis leist thierry
# 2385416        937123       410124                    kay williams
#
#            BIRTH_DT  Unnamed: 0_y                              name  \
# 3910079  1983-12-05        114182               samantha lewthwaite
# 63299    1950-06-05        135512              hafiz muhammad saeed
# 3949303  1942-03-21        154536                ali abdullah saleh
# 4710735  1956-01-10        148081  eliecer herlinto chamorro acosta
# 4502076  1950-05-12        134692           ivanov victor petrovich
# ...             ...           ...                               ...
# 2135354  1978-08-25        153456                     ana hernandez
# 1738556  1962-07-10         25372           isabella sanchez robles
# 1249796  1959-05-22        166116                      ian campbell
# 1249586  1959-05-22        166116                      ian campbell
# 2385416  1974-06-07        128660                    craig williams
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 63299    [hafiz muhammad saeed, hafiz saab sayed, hafiz...          88
# 3949303  ['ali 'abd allah saleh, 'ali 'abd allah salih,...          86
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 4502076  [ivanov  victor petrovich, ivanov  viktor, vic...          85
# ...                                                    ...         ...
# 2135354  [ana e. hernandez, ana hernanenz, ана хернанде...          87
# 1738556  [isabel sanchez robles, isabel sánchez, sánche...          76
# 1249796  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 1249586  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 2385416  [alun craig williams, craig williams (politici...          80
#
#          aliases_score                      aliases_name
# 3910079            100        samantha louise lewthwaite
# 63299              100                    hafez mohammad
# 3949303            100             'ali 'abd allah salih
# 4710735            100  eliecer herlinto chamorro acosta
# 4502076            100                    ivanov  viktor
# ...                ...                               ...
# 2135354             81                  ana e. hernandez
# 1738556             80             isabel sanchez robles
# 1249796             80                     campbell  ian
# 1249586             80                     campbell  ian
# 2385416             80               alun craig williams
#
# [66 rows x 10 columns]

# %%
x.columns
# Out:
# Index(['Unnamed: 0_x', 'CUSTOMER_ID', 'NAME', 'BIRTH_DT', 'Unnamed: 0_y',
#        'name', 'aliases', 'name_score', 'aliases_score', 'aliases_name'],
#       dtype='object')

# %%
x=x[['CUSTOMER_ID', 'NAME', 'BIRTH_DT','name', 'aliases', 'name_score', 'aliases_score', 'aliases_name']]

# %%
x
# Out:
#          CUSTOMER_ID                            NAME    BIRTH_DT  \
# 3910079        52501             samantha lewthwaite  1983-12-05
# 63299         711085           sayeed hafez mohammad  1950-06-05
# 3949303       507823             ali abd allah salih  1942-03-21
# 4710735       592809        herlinto chamorro acosta  1956-01-10
# 4502076       165089        viktor petrovitsj ivanov  1950-05-12
# ...              ...                             ...         ...
# 2135354       587233               chandra hernandez  1978-08-25
# 1738556       424548     robles michael doby sanchez  1962-07-10
# 1249796       751322     davis betty campbell bowman  1959-05-22
# 1249586       699067  campbell phyllis leist thierry  1959-05-22
# 2385416       410124                    kay williams  1974-06-07
#
#                                      name  \
# 3910079               samantha lewthwaite
# 63299                hafiz muhammad saeed
# 3949303                ali abdullah saleh
# 4710735  eliecer herlinto chamorro acosta
# 4502076           ivanov victor petrovich
# ...                                   ...
# 2135354                     ana hernandez
# 1738556           isabella sanchez robles
# 1249796                      ian campbell
# 1249586                      ian campbell
# 2385416                    craig williams
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 63299    [hafiz muhammad saeed, hafiz saab sayed, hafiz...          88
# 3949303  ['ali 'abd allah saleh, 'ali 'abd allah salih,...          86
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 4502076  [ivanov  victor petrovich, ivanov  viktor, vic...          85
# ...                                                    ...         ...
# 2135354  [ana e. hernandez, ana hernanenz, ана хернанде...          87
# 1738556  [isabel sanchez robles, isabel sánchez, sánche...          76
# 1249796  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 1249586  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 2385416  [alun craig williams, craig williams (politici...          80
#
#          aliases_score                      aliases_name
# 3910079            100        samantha louise lewthwaite
# 63299              100                    hafez mohammad
# 3949303            100             'ali 'abd allah salih
# 4710735            100  eliecer herlinto chamorro acosta
# 4502076            100                    ivanov  viktor
# ...                ...                               ...
# 2135354             81                  ana e. hernandez
# 1738556             80             isabel sanchez robles
# 1249796             80                     campbell  ian
# 1249586             80                     campbell  ian
# 2385416             80               alun craig williams
#
# [66 rows x 8 columns]

# %%
#x.to_csv('bad_actors_list_v1.csv')

# %% [markdown]
# # Let us try to reduce false positive from this list
#
# 1. On a general observation all those aliases score where score is 100 by the match aliases is only a single word we should reject those as they are highly unlikely since only one word from the entire name is matching. However there should be check if the customer name is also one.

# %%
x['aliases_len']=x['aliases_name'].str.split(" ").str.len()
# Out:
# <ipython-input-105-109acf5cd4a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['aliases_len']=x['aliases_name'].str.split(" ").str.len()

# %%
x['name_len']=x['NAME'].str.split(" ").str.len()

# %%
x
# Out:
#          CUSTOMER_ID                            NAME    BIRTH_DT  \
# 3910079        52501             samantha lewthwaite  1983-12-05
# 63299         711085           sayeed hafez mohammad  1950-06-05
# 3949303       507823             ali abd allah salih  1942-03-21
# 4710735       592809        herlinto chamorro acosta  1956-01-10
# 4502076       165089        viktor petrovitsj ivanov  1950-05-12
# ...              ...                             ...         ...
# 2135354       587233               chandra hernandez  1978-08-25
# 1738556       424548     robles michael doby sanchez  1962-07-10
# 1249796       751322     davis betty campbell bowman  1959-05-22
# 1249586       699067  campbell phyllis leist thierry  1959-05-22
# 2385416       410124                    kay williams  1974-06-07
#
#                                      name  \
# 3910079               samantha lewthwaite
# 63299                hafiz muhammad saeed
# 3949303                ali abdullah saleh
# 4710735  eliecer herlinto chamorro acosta
# 4502076           ivanov victor petrovich
# ...                                   ...
# 2135354                     ana hernandez
# 1738556           isabella sanchez robles
# 1249796                      ian campbell
# 1249586                      ian campbell
# 2385416                    craig williams
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 63299    [hafiz muhammad saeed, hafiz saab sayed, hafiz...          88
# 3949303  ['ali 'abd allah saleh, 'ali 'abd allah salih,...          86
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 4502076  [ivanov  victor petrovich, ivanov  viktor, vic...          85
# ...                                                    ...         ...
# 2135354  [ana e. hernandez, ana hernanenz, ана хернанде...          87
# 1738556  [isabel sanchez robles, isabel sánchez, sánche...          76
# 1249796  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 1249586  [campbell  ian, ian gordon campbell, йен кэмпб...          80
# 2385416  [alun craig williams, craig williams (politici...          80
#
#          aliases_score                      aliases_name  aliases_len  \
# 3910079            100        samantha louise lewthwaite            3
# 63299              100                    hafez mohammad            2
# 3949303            100             'ali 'abd allah salih            4
# 4710735            100  eliecer herlinto chamorro acosta            4
# 4502076            100                    ivanov  viktor            3
# ...                ...                               ...          ...
# 2135354             81                  ana e. hernandez            3
# 1738556             80             isabel sanchez robles            3
# 1249796             80                     campbell  ian            3
# 1249586             80                     campbell  ian            3
# 2385416             80               alun craig williams            3
#
#          name_len
# 3910079         2
# 63299           3
# 3949303         4
# 4710735         3
# 4502076         3
# ...           ...
# 2135354         2
# 1738556         4
# 1249796         4
# 1249586         4
# 2385416         2
#
# [66 rows x 10 columns]

# %%
x=x[~(x['aliases_len']==1) & (x['name_len']!=1)]

# %%
x=x[x['aliases_score']>=90]

# %%
x
# Out:
#          CUSTOMER_ID                               NAME    BIRTH_DT  \
# 3910079        52501                samantha lewthwaite  1983-12-05
# 63299         711085              sayeed hafez mohammad  1950-06-05
# 3949303       507823                ali abd allah salih  1942-03-21
# 4710735       592809           herlinto chamorro acosta  1956-01-10
# 4502076       165089           viktor petrovitsj ivanov  1950-05-12
# 306089         87457    michail aleksandrovitj afanasov  1953-06-05
# 1269775       344527         assiri ibrahim hassan tali  1982-04-19
# 1191595       376264           oleksin alexei ivanovich  1966-10-29
# 1464324       962029         ayeras ricardo abdulkareem  1973-09-15
# 5061548       181586                      b m mclachlin  1943-09-07
# 2373385       121103                 emilie samra konig  1984-12-09
# 1089488       584841    al zawahiri aiman muhammad rabi  1951-06-19
# 2414934       756175              leonid i kalaschnikow  1960-08-06
# 4364006       883073                   smirnova natalia  1972-06-15
# 4017966       273457   andrei konstantinowitsj loegowoi  1966-10-19
# 1500961       621578      shongole fuad muhammad khalaf  1965-05-28
# 1810143       404022                mazhuga aleksandr g  1980-08-06
# 2521251       773937                    viktoria rodina  1989-10-29
# 4700096       659167                         yon jun jo  1937-09-28
# 4276296       436195                hammami omar shafik  1986-05-06
# 4413900       288061       tsertsel ivan stanislavavich  1966-09-08
# 1081468       359412            alison merrilla redford  1965-03-07
# 1697162        57584                 heather ann wilson  1960-12-30
# 3165877       358968                   jones sally anne  1968-11-17
# 2418290       708895  ivan luciano marquez marin arango  1955-06-06
# 3688784       618677                         o jong gil  1962-08-30
# 1513353       752207        bezrukov sergey vitalyevich  1973-10-18
# 3004424       178391               paul franklin watson  1950-12-02
# 900597        763368         zheynova marina nikolaevna  1985-02-15
# 395813        894044                    hlaing min aung  1956-07-03
# 3480847       479020          rakhim azizboevich azimov  1964-08-16
# 4524007       979769                cesar duarte jaquez  1963-04-14
# 542254        948991            el hassan gaffar mohmed  1952-06-24
# 2850285       853027     tetiana viktorivna pereverzeva  1964-06-20
# 2786695       139717          alexey alexeyevich gromov  1960-05-31
# 4831138       251483                john kelly williams  1946-12-31
# 4857457       230856                       se pong paek  1938-03-21
# 2570713       901009                       cheraf peter  1982-08-26
# 664120        594147                        pom su jang  1957-04-15
# 3959664       251691                    maria bono mack  1961-10-24
# 2174042       765620          trinidad y ramirez angelo  1978-03-20
# 250633        917730         jose benito cabrera cuevas  1963-07-06
# 1821803       888132         azarenok grigori yurievich  1994-10-18
# 2875948       616682  poklonskaya natalija vladimirovna  1980-03-18
# 2057073       199303                david miller moreno  1953-01-29
#
#                                      name  \
# 3910079               samantha lewthwaite
# 63299                hafiz muhammad saeed
# 3949303                ali abdullah saleh
# 4710735  eliecer herlinto chamorro acosta
# 4502076           ivanov victor petrovich
# 306089     mikhail alexandrovich afanasov
# 1269775           ibrahim hassan al asiri
# 1191595         aleksej ivanovitj oleksin
# 1464324              ricardo perez ayeras
# 5061548                beverley mclachlin
# 2373385               emilie edwige konig
# 1089488                 ayman al zawahiri
# 2414934      kalashnikov leonid ivanovich
# 4364006          smirnova natalya ivanova
# 4017966    andrey konstantinovich lugovoy
# 1500961               fuad mohamed khalaf
# 1810143     alexander georgievich mazhuga
# 2521251         victoria sergeevna rodina
# 4700096                       cho yon jun
# 4276296                      omar hammami
# 4413900        ivan stanislavavich tertel
# 1081468                    alison redford
# 1697162                    heather wilson
# 3165877          sally anne frances jones
# 2418290             marin arango  luciano
# 3688784                        jong gil o
# 1513353       sergey vitalyevich bezrukov
# 3004424              paul franklin watson
# 900597         marina nikolaevna zheynova
# 395813                    min aung hlaing
# 3480847          rahim azizboevich asimov
# 4524007       cesar horacio duarte jaquez
# 542254           gaffar mohammed elhassan
# 2850285    tatiana viktorovna pereverzeva
# 2786695         alexey alexeyevich gromov
# 4831138                  john g  williams
# 4857457                      se bong paek
# 2570713                      peter cherif
# 664120                        jang bom su
# 3959664                    mary bono mack
# 2174042           angelo ramirez trinidad
# 250633                jose benito cabrera
# 1821803      grigoriy yur yevich azarenok
# 2875948  natalia vladimirovna poklonskaya
# 2057073                      david miller
#
#                                                    aliases  name_score  \
# 3910079  [bílá vdova, samantha louise lewthwaite, saman...         100
# 63299    [hafiz muhammad saeed, hafiz saab sayed, hafiz...          88
# 3949303  ['ali 'abd allah saleh, 'ali 'abd allah salih,...          86
# 4710735  [antonio garcia, antonio garcia (guerrillero),...         100
# 4502076  [ivanov  victor petrovich, ivanov  viktor, vic...          85
# 306089   [afanasov mikhail alexandrovich, afanasov  mik...          85
# 1269775  ['asiri  ibrahim hasan tali'a, abosslah, abu s...          82
# 1191595  [aleksin  aliaksei, aleksin  aliaksey, aleksin...          82
# 1464324  [ayeras  abdul kareem, ayeras  abdul karem, ay...          82
# 5061548  [b m mclachlin, b. m. mclachlin, beverley giet...          82
# 2373385  [emilie edwige konig, emilie konig, emilie edw...          80
# 1089488  [aiman muhammed rabi al-zawahiri, aiman muhamm...          79
# 2414934  [kalashnikov  leonid ivanovich, kalashnikov le...          78
# 4364006  [natalia smirnova, natalya ivanova smirnova, n...          75
# 4017966  [andrei (andrey) lugovoi (lugovoy), andrei kon...          74
# 1500961  [fuad mohamed khalaf, fouad shongale, fouad sh...          73
# 1810143  [aleksandr (alexander) mazhuga, aleksandr geor...          71
# 2521251  [rodina victoria sergeevna, rodina  victoria s...          70
# 4700096  [cho yon chun, cho  yon chun, cho yon chun, ch...          86
# 4276296  [al-amriki  abu mansour, al-amriki  abu mansur...         100
# 4413900  [ivan stanislavavich tsertsel, ivan stanislava...          96
# 1081468  [alison merrilla redford, άλισον ρέντφορντ, ел...         100
# 1697162  [heather ann wilson, wilson, wilson  heather, ...         100
# 3165877  [al-britani  umm hussain, hussain  sakinah, jo...         100
# 2418290  [ivan luciano marquez marin arango, ivan marqu...         100
# 3688784                           [jong gil o, o jong gil]         100
# 1513353  [bezrukov sergei vitalevich, bezrukov sergey v...         100
# 3004424  [paul franklin watson, paul watson, пол ватсон...         100
# 900597   [marina nikolaevna zheynova, marina nikolajevn...         100
# 395813   [el pinochet birmano, hlaing  min aung, jenera...         100
# 3480847  [asimov  rahim azizboyevich, azimov rakhim azi...          94
# 4524007  [cesar horacio duarte jaquez, cesar duarte jaq...         100
# 542254   [(gaffar mohmed elhassan), el hassan  gaffar m...          94
# 2850285  [pereverzeva tatyana viktorovna, pereverzeva  ...          93
# 2786695  [a. gromov, aleksei gromov, aleksej aleksejevi...         100
# 4831138  [john williams, جون جى. وليامز, جون جي. وليامز...          93
# 4857457  [paek se bong, paek  se pong, paek  se-bong, p...          92
# 2570713  [cheraf  abu hamza, cheraf  peter, cherif  pet...          92
# 664120   [bom su jang, hyon u jang, jang hyon u, jang p...          91
# 3959664  [bono mack, bono mack  mary, maria bono, maria...          90
# 2174042  [angelo ramirez trinidad, abdukahlil, abdul kh...         100
# 250633   [fabian ramirez, fabian ramírez, fabián ramíre...         100
# 1821803  [azarenok grigori yur'yevich, azarenok grigori...          85
# 2875948  [dubrovskaia natalia vladimirovna, dubrovskaja...          98
# 2057073  [david miller (wyoming politician), david r. m...         100
#
#          aliases_score                       aliases_name  aliases_len  \
# 3910079            100         samantha louise lewthwaite            3
# 63299              100                     hafez mohammad            2
# 3949303            100              'ali 'abd allah salih            4
# 4710735            100   eliecer herlinto chamorro acosta            4
# 4502076            100                     ivanov  viktor            3
# 306089             100    michail aleksandrovitj afanasov            3
# 1269775            100        assiri  ibrahim hassan tali            5
# 1191595            100           alexei ivanovich oleksin            3
# 1464324            100        ayeras  ricardo abdulkareem            4
# 5061548            100                      b m mclachlin            3
# 2373385            100                       emilie konig            2
# 1089488            100   al-zawahiri  aiman muhammad rabi            5
# 2414934            100             leonid i. kalaschnikow            3
# 4364006            100                   natalia smirnova            2
# 4017966            100   andrei konstantinowitsj loegowoi            3
# 1500961            100                        fuad khalaf            2
# 1810143            100                  aleksandr mazhuga            2
# 2521251            100                    viktoria rodina            2
# 4700096            100                         jo yon jun            3
# 4276296            100                      hammami  omar            3
# 4413900            100       ivan stanislavavich tsertsel            3
# 1081468            100            alison merrilla redford            3
# 1697162            100                 heather ann wilson            3
# 3165877            100                       jones  sally            3
# 2418290            100  ivan luciano marquez marin arango            5
# 3688784            100                         jong gil o            3
# 1513353            100        bezrukov sergey vitalyevich            3
# 3004424            100               paul franklin watson            3
# 900597             100         marina nikolaevna zheynova            3
# 395813             100                   hlaing  min aung            4
# 3480847            100          azimov rakhim azizboevich            3
# 4524007            100        cesar horacio duarte jaquez            4
# 542254             100           el hassan  gaffar mohmed            5
# 2850285            100    pereverzeva  tetiana viktorivna            4
# 2786695            100          alexey alexeyevich gromov            3
# 4831138            100                      john williams            2
# 4857457            100                      paek  se pong            4
# 2570713            100                      cheraf  peter            3
# 664120             100                        jang pom su            3
# 3959664            100                          bono mack            2
# 2174042            100            angelo ramirez trinidad            3
# 250633             100                jose benito cabrera            3
# 1821803             98        azarenok grigoriy yurievich            3
# 2875948             98   natalia vladimirovna poklonskaya            3
# 2057073             92                    david r. miller            3
#
#          name_len
# 3910079         2
# 63299           3
# 3949303         4
# 4710735         3
# 4502076         3
# 306089          3
# 1269775         4
# 1191595         3
# 1464324         3
# 5061548         3
# 2373385         3
# 1089488         5
# 2414934         3
# 4364006         2
# 4017966         3
# 1500961         4
# 1810143         3
# 2521251         2
# 4700096         3
# 4276296         3
# 4413900         3
# 1081468         3
# 1697162         3
# 3165877         3
# 2418290         5
# 3688784         3
# 1513353         3
# 3004424         3
# 900597          3
# 395813          3
# 3480847         3
# 4524007         3
# 542254          4
# 2850285         3
# 2786695         3
# 4831138         3
# 4857457         3
# 2570713         2
# 664120          3
# 3959664         3
# 2174042         4
# 250633          4
# 1821803         3
# 2875948         3
# 2057073         3

# %%
x.shape
# Out:
# (45, 10)

# %%
x.to_csv('filtered_bad_actor_list.csv')

# %% [markdown]
# # Please try word embeddings
