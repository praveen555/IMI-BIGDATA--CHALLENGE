# %% [markdown]
# <a href="https://colab.research.google.com/github/praveen555/IMI-BIGDATA--CHALLENGE/blob/main/kYC_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
pip install python-levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 KB 4.2 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 40.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-levenshtein
# Successfully installed Levenshtein-0.20.9 python-levenshtein-0.20.9 rapidfuzz-2.13.7

# %%
import os
import pandas as pd
import re 
import matplotlib.pyplot as plt
from datetime import datetime, date
import numpy as np
from google.colab import drive
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
drive.mount('/content/drive')
path='/content/drive/MyDrive/Colab Notebooks/IMI_BigData_Challenge/Raw data files'
path_2='/content/drive/MyDrive/Colab Notebooks/IMI_BigData_Challenge/Task_1_Data'
path_edge=os.path.join(path,'UofT_edges.csv')
path_nodes=os.path.join(path,'UofT_nodes.csv')
path_occupation_risk=os.path.join(path,'UofT_occupation_risk.csv')
path_name_list='/content/drive/MyDrive/Colab Notebooks/IMI_BigData_Challenge/name_list.csv'
path_clean_customer=os.path.join(path_2,'clean_customer_names.csv')
path_clean_sanctions=os.path.join(path_2,'clean_sanction_names.csv')
# Out:
# Mounted at /content/drive

# %%
customer_names=pd.read_csv(path_clean_customer)

# %%
sanction_names=pd.read_csv('sanctioned_clean_names.csv')

# %%
customer_names
# Out:
#         Unnamed: 0                            NAME    BIRTH_DT  \
# 0                0    Young, Marie Mildren Coleman  1981-09-01
# 1                1                Mark Stupar Lecy  1994-02-21
# 2                2      Dean Glasper Wendel Reeves  1962-11-16
# 3                3             Hulsey, Linda Rauth  1998-06-20
# 4                4      Carolyn Washington Roberts  1942-01-24
# ...            ...                             ...         ...
# 999335      999995               Bret* Dove Gainey  1939-01-16
# 999336      999996       Anthony Ray Montano Gomez  1970-12-13
# 999337      999997  Bernadette Schofield Pace Mile  1958-09-09
# 999338      999998         Wasson, Russell Terrell  1983-09-15
# 999339      999999                Daniel Mckeighan  1962-01-23
#
#                          cleaned_names
# 0         young  marie mildren coleman
# 1                     mark stupar lecy
# 2           dean glasper wendel reeves
# 3                  hulsey  linda rauth
# 4           carolyn washington roberts
# ...                                ...
# 999335               bret  dove gainey
# 999336       anthony ray montano gomez
# 999337  bernadette schofield pace mile
# 999338         wasson  russell terrell
# 999339                daniel mckeighan
#
# [999340 rows x 4 columns]

# %%
sanction_names
# Out:
#         Unnamed: 0                           names  \
# 0                0                  kolyvanov egor
# 1                1         shipov sergei yurievich
# 2                2        egorov ivan mikhailovich
# 3                3  goreslavsky alexey sergeyevich
# 4                4  samoilova natalya vladimirovna
# ...            ...                             ...
# 108959      240801     novosyolova nadiya yuriivna
# 108960      240803     in french by lambert jérôme
# 108961      240805     lavrov vladimir valerievich
# 108962      240806   doroshko valentin valerievich
# 108963      240807               al-hamali mohamed
#
#                                aliases  birth_date
# 0                       Колыванов Егор  1980-11-15
# 1                 Шипов Сергей Юрьевич  1966-04-17
# 2               Егоров Иван Михайлович  1961-01-21
# 3       Гореславский Алексей Сергеевич  1977-07-13
# 4       Самойлова Наталья Владимировна  1987-06-24
# ...                                ...         ...
# 108959      Новоселова Надежда Юрьевна  1979-11-26
# 108960                    Ламбер Жером  1957-07-07
# 108961    Лавров Володимир Валерійович  1983-10-19
# 108962    Дорошко Валентин Валерійович  1984-10-02
# 108963               Al-Hamali Mohamed  1991-08-20
#
# [108964 rows x 4 columns]

# %%
sanction_names.rename(columns={'birth_date':"BIRTH_DT"},inplace=True)

# %%
sanction_names.head(2)
# Out:
#    Unnamed: 0                    names               aliases    BIRTH_DT
# 0           0           kolyvanov egor        Колыванов Егор  1980-11-15
# 1           1  shipov sergei yurievich  Шипов Сергей Юрьевич  1966-04-17

# %%
df=pd.merge(customer_names,sanction_names,on='BIRTH_DT')

# %%
df
# Out:
#          Unnamed: 0_x                          NAME    BIRTH_DT  \
# 0                   0  Young, Marie Mildren Coleman  1981-09-01
# 1                   0  Young, Marie Mildren Coleman  1981-09-01
# 2                   0  Young, Marie Mildren Coleman  1981-09-01
# 3                   0  Young, Marie Mildren Coleman  1981-09-01
# 4                   0  Young, Marie Mildren Coleman  1981-09-01
# ...               ...                           ...         ...
# 3892223        991613  Clarissa Smith Henley Martin  1918-02-08
# 3892224        994339               June Vick Fultz  1921-04-21
# 3892225        994339               June Vick Fultz  1921-04-21
# 3892226        998751            Nick Tamayo Turner  1925-08-31
# 3892227        998751            Nick Tamayo Turner  1925-08-31
#
#                         cleaned_names  Unnamed: 0_y                 names  \
# 0        young  marie mildren coleman         61409     petrovic, zelimir
# 1        young  marie mildren coleman        128964           matt warman
# 2        young  marie mildren coleman        139893  alfredo anaya orozco
# 3        young  marie mildren coleman        142779           terry healy
# 4        young  marie mildren coleman        121647  jose ignacio beating
# ...                               ...           ...                   ...
# 3892223  clarissa smith henley martin        189445             max rayne
# 3892224               june vick fultz          8279       pierre teuscher
# 3892225               june vick fultz        127020       nicolaus dreyer
# 3892226            nick tamayo turner        166671         dewey l. hill
# 3892227            nick tamayo turner        193988       shirley walters
#
#                                                    aliases
# 0                                         Zelimir Petrovic
# 1        Matthew Robert Warman;Warman, Matt;مات وارمان;...
# 2                                     Anaya Orozco Alfredo
# 3                            Terence James Healy;تيري هيلي
# 4        Jose Ignacio Paliza;Jose Paliza;José Ignacio P...
# ...                                                    ...
# 3892223                   Max Rayne, Baron Rayne;ماكس راين
# 3892224                                   Teuscher, Pierre
# 3892225              Dreyer!;Nikolaus Dreyer;نيكولاوس درير
# 3892226  Dewey Lewis Hill;ديوى ال. هيل;ديوي إل. هيل;دیو...
# 3892227    Mary Shirley Walters;Mary Walters;Walters, Mary
#
# [3892228 rows x 7 columns]

# %%
def fuzzyscore(col):
  return fuzz.token_set_ratio(col['cleaned_names'],col['names'])

# %%
df['score']=df.apply(fuzzyscore,axis=1)

# %%
high_risk_names=df[(df['score']==76)]

# %%
high_risk_names.shape
# Out:
# (29, 8)

# %%
high_risk_names.sort_values('score',ascending=False,inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%